# %% [markdown]
# # Seaborn Inroduction

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
# Distribution Plots

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# distribution plot
# for distribution plot just pass single column of data frame

sns.distplot(tips['total_bill'])
sns.set_style('whitegrid')

# %%
sns.set_style('whitegrid')
# chaning the style of the grid

# %%
sns.set_style("dark")
sns.set_style("darkgrid")
sns.set(style="darkgrid", color_codes=True)

# %%
sns.distplot(tips['total_bill'])

# distribution plot
# for distribution plot just pass single column of data frame

# we get a histogram and kde (kernel density estimation)
# we can also remove it by saying kde = false

# %%
sns.distplot(tips['total_bill'], kde = False)

# %%
#changinge number of bins

sns.distplot(tips['total_bill'], kde = False, bins = 30)

# %%
# Joint plots
# allow us to match up two distribution(dist plot) by bbivariant data
# 2 distribution plots
# tips on the y-axis  nad total_bill on x-axis
# then we have a scatter plot
#if you go higer in total bill you go higer in total tip

sns.jointplot(x='total_bill', y='tip', data = tips)

# %%
# Joint plots
# allow us to match up two distribution(dist plot) by bbivariant data
# 2 distribution plots
# tips on the y-axis  nad total_bill on x-axis
# then we have a scatter plot
#if you go higer in total bill you go higer in total tip
#kind parameter allows you to affect what's going on inside of joint plot
#right now by default its set to scatter but we can also chnage it to hex

sns.jointplot(x='total_bill', y='tip', data = tips,kind = 'hex' )
# hexagonal distribution
# if heagonal has certain number of points in it , it gets darker 
# so it doesnt show all scatter points sometimes but inform us based on contrast i.e
# dark and light

# %%
import seaborn as sns
import scipy.stats as stats

# %%
sns.set_style("dark")
sns.set_style("darkgrid")
sns.set(style="darkgrid", color_codes=True)

# %%
sns.jointplot(x='total_bill', y='tip', data = tips,kind ='reg' ).annotate(stats.pearsonr)

sns.jointplot(x='total_bill', y='tip', data = tips,kind ='reg'
              ,stat_func=stats.pearsonr)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
sns.jointplot(x='total_bill', y='tip', data= tips,kind ='kde'
              ,stat_func=stats.pearsonr)

# kde shows the desnsity where these points match up the most
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#pair plots
#it will plot a pariwise relationship across an entire dataframe
# atleast for the numerical data and it also supports categoraical column
# pair plot will perfom a joint plot for every single possible combinations
# of the numerical columns in the data frame


sns.pairplot(tips)

# pairplot for all numerical value

# %%
#pair plots
#it will plot a pariwise relationship across an entire dataframe
# atleast for the numerical data and it also supports categoraical column
# pair plot will perfom a joint plot for every single possible combinations
# of the numerical columns in the data frame


# hue is a parameter where we will pass the name of the column that has a 
# categorical data

sns.pairplot(tips, hue = 'sex')

# the data will be divided into male and female

# pairplot for all numerical value

# %%
#pair plots
#it will plot a pariwise relationship across an entire dataframe
# atleast for the numerical data and it also supports categoraical column
# pair plot will perfom a joint plot for every single possible combinations
# of the numerical columns in the data frame


# hue is a parameter where we will pass the name of the column that has a 
# categorical data

sns.pairplot(tips, hue = 'sex', palette ='coolwarm')

# the data will be divided into male and female

# pallette is a parameter through which we can change the color

# pairplot for all numerical value

# %%
#rug plots

sns.rugplot(tips['total_bill'])

#rug plot marks the dashmark for every point on this uniform or univariant
# distribution unlike historgram
#histogram counts the dast marks and show them as 1 bin

# %%
sns.distplot(tips['total_bill'], kde = False)

# %%
#kde plot
# how do we create / make a kde line based off on the rugplots
#kde = kernel density estimation plots
# building the kde line
#go to wikipedia of kde


#there are gausian distribution on top of each point/dashmark and sum them
#up to get the KDE

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    # plots a normal distribution for each of the rug plot point
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)


# the grey lines are the normal distribution on top of each blue dash
# now we sum them in next part to get the kde
# Out:
# (0, 1)

# %%
# To get the kde plot we can sum these basis functions.

# Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plot figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

# Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Get rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Functions')

# %% [markdown]
# # Categorical Plots

# %%
import seaborn as sbs
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot( x = 'sex', y = 'total_bill', data = tips)


# categorical plots:  will focus on distributions of catergorical coumns such
# sex, smoker, day, time

# the basic categorical plot is barplot
# the barplot allow us to aggregate the  categorical data based of sum function,
# by default  the function  is mean and will calculate mean
#its like a visualization of groupby action

# x-axis = categorical column
# y-axis = numeric

# by default we are seeing average / mean for male and female
# we can change the estimator object to change the function(shift + Tab)
# we can also add our own functions

# %%
import numpy as np

# %%
sns.barplot( x = 'sex', y = 'total_bill', data = tips, estimator = np.std )


# categorical plots:  will focus on distributions of catergorical coumns such
# sex, smoker, day, time

# the basic categorical plot is barplot
# the barplot allow us to aggregate the  categorical data based of sum function,
# by default  the function  is mean and will calculate mean
#its like a visualization of groupby action

# x-axis = categorical column
# y-axis = numeric

# by default we are seeing average / mean for male and female
# we can change the estimator object to change the function(shift + Tab)

# we are passing the numpy function in the estimator

# %%
sns.countplot(x = 'sex', data = tips)

#simple plot

# %% [markdown]
# # Box plot and Voilin Plot

# %%
#boxplot split per day
sns.boxplot(x= 'day', y='total_bill', data = tips)

# %%
sns.boxplot(x= 'day', y='total_bill', data = tips, hue = 'smoker')
#box plot split per day and by smoker

# %%
#boxplot split per day
sns.boxplot(x= 'day', y='total_bill', data = tips)

# %%
#violinplot
# violin plot  unlike the boxplot, allow us to plot all the components that
# corresponds the actial data points and it shows the kerel densdity estimation
# of the underlying distribution.
# if we spit the graph into half we can see that it shows the distribution of the
# points on it's side, hence giving us more detail. However they are bit harder
# to read as compared to box plot

sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
#violinplot
# violin plot  unlike the boxplot, allow us to plot all the components that
# corresponds the actial data points and it shows the kerel densdity estimation
# of the underlying distribution.
# if we spit the graph into half we can see that it shows the distribution of the
# points on it's side, hence giving us more detail. However they are bit harder
# to read as compared to box plot
# adding hue

sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow', hue ='sex')

# %%
#violinplot
# violin plot  unlike the boxplot, allow us to plot all the components that
# corresponds the actial data points and it shows the kerel densdity estimation
# of the underlying distribution.
# if we spit the graph into half we can see that it shows the distribution of the
# points on it's side, hence giving us more detail. However they are bit harder
# to read as compared to box plot

#hue and split added

sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow', hue ='sex', split = 'True')

# %%
# strip plot will draw a scatter plot with one vairbale as a categorical and one 
#numerical.

# we canno't tell hw many points are actaully there but we can use jitter
# to filter some of the overlappings and see a better version (more points)

sns.stripplot(x="day", y="total_bill", data=tips)

# %%
# strip plot will draw a scatter plot with one vairbale as a categorical and one 
#numerical.

# we canno't tell hw many points are actaully there but we can use 
# to filter some of the overlappings and see a better version (more points)/better density

sns.stripplot(x="day", y="total_bill", data=tips, jitter = True)

# %%
# strip plot will draw a scatter plot with one vairbale as a categorical and one 
#numerical.

# we canno't tell hw many points are actaully there but we can use 
# to filter some of the overlappings and see a better version (more points)/better density

sns.stripplot(x="day", y="total_bill", data=tips, jitter = True, hue= 'sex',split=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
# strip plot will draw a scatter plot with one vairbale as a categorical and one 
#numerical.

# we canno't tell hw many points are actaully there but we can use 
# to filter some of the overlappings and see a better version (more points)/better density

sns.stripplot(x="day", y="total_bill", data=tips, jitter = True, hue= 'sex',dodge=True)

# %%
# swarm plot is combination of voilin and striplot
# swarm plot is similar to stripplot, the points are adjusted so that they don't overlap
# hence a better represenations

#sometime there are issues with scalling and not suitable for large dataset

sns.swarmplot(x="day", y="total_bill", data=tips)

# %%
# swarm plot is combination of voilin and striplot
# swarm plot is similar to stripplot, the points are adjusted so that they don't overlap
# hence a better represenations

#sometime there are issues with scalling and not suitable for large dataset

# swarm and voilin together
#not suitable for exectuive mettings or for presentation

sns.violinplot(x="day", y="total_bill", data=tips)

sns.swarmplot(x="day", y="total_bill", data=tips, color = 'black')

# %%
#factor plot

sns.factorplot(x='day',y='total_bill',data=tips,kind='bar')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#factor plot

sns.catplot(x='day',y='total_bill',data=tips,kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b872037ce557> in <module>
#       1 #factor plot
#       2
# ----> 3 sns.factorplot(x='day',y='total_bill',data=tips,kind='bar')
#
# NameError: name 'sns' is not defined

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
# Heat Map works properly when the data is in a matrix form
# matrix form means that the index name  and the column name
# matchup so that the cell value actually indicates something 
# that is relevant to both of the names

# we will convert to matrix by using correlation and pivot method

# %%
tc = tips.corr()
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc)

# %%
sns.heatmap(tc, annot = True)

# %%
sns.heatmap(tc, annot = True, cmap = 'coolwarm')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
#converting to matrix using pivot

fp = flights.pivot_table(index = 'month', columns = 'year', values ='passengers')
fp
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(fp)

# %%
sns.heatmap(fp,cmap= 'magma')

# %%
cmap = sns.cm.rocket_r

#The default cmap is sns.cm.rocket. To reverse it set cmap to sns.cm.rocket_r

# %%
sns.heatmap(fp,cmap= cmap)

# %%
sns.heatmap(fp,cmap= cmap, linecolor = 'white', linewidth = 1 , #annot = True
           )

# %%
sns.heatmap(fp,cmap= 'coolwarm', linecolor = 'black', linewidth = 2 , #annot = True
           )

# %%
sns.heatmap(fp, alpha = 0.5)

# %%
# Cluster map

sns.clustermap(fp)

# the columns and rows are clustered based on the similarity in pattern

#normalization from 0 to 100 instad of 0 to 600

# %%
sns.clustermap(fp, cmap='coolwarm', standard_scale = 1)

# %%
sns.clustermap(fp, cmap='red', standard_scale = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-e55e7dba2a9e> in <module>
# ----> 1 sns.clustermap(fp, cmap='red', standard_scale = 1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1389                         row_cluster=row_cluster, col_cluster=col_cluster,
#    1390                         row_linkage=row_linkage, col_linkage=col_linkage,
# -> 1391                         tree_kws=tree_kws, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, tree_kws, **kws)
#    1217
# ...

# %% [markdown]
# # Grid

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# %matplotlib inline
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.set_style("dark")
sns.set_style("darkgrid")
sns.set(style="darkgrid", color_codes=True)

# %%
sns.pairplot(iris)

# %%
#customizing pairplot with more freedom


g = sns.PairGrid(iris)
g
#we see an empty version of a pairplot

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
# Facet Grid





tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(data = tips, col ='time', row = 'smoker' )
g.map(sns.distplot, 'total_bill')



#xaxis = total_bill
# yes and no are smoker
# left col is lunch
# right col is dinner
# top row smoker no
# bottom row smoker yes

#4 distribution plots

# %%
g = sns.FacetGrid(data = tips, col ='time', row = 'smoker' )
g.map(plt.scatter, 'total_bill', 'tip')

#we can also add second argumnet in this case tip in the map function

# %% [markdown]
# #  Regression plots

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips)

# %%
 sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm', markers = ['o','v'])

# we can add our own markers
# the markers come from matplotlib
# since we have a hue here we will have two markers

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex', markers = ['o','v'],
          scatter_kws = {'s':100})

# we can add our own markers
# the markers come from matplotlib
# since we have a hue here we will have two markers

# calling matplot directly from seaborn :
    #sns.lmplot is calling matplotlib under the hood
    #we can effect matlplotlib diretly from seaborn
    #it will be a case to case bases, (different ofr each case)
    # in this case we need to pass a dictionary to change the size of markers
    
    
#we are passing a dictionary based with matplotlib arguments, s is for size of scatterplot

# %%
# seperating by columns
#instead of hue

sns.lmplot(x='total_bill',y='tip',data=tips, col='sex')

# %%
# seperating by columns
#instead of hue
#and rows

sns.lmplot(x='total_bill',y='tip',data=tips, col='sex', row = 'time')

# %%
# seperating by columns
#instead of hue
#and rows

#ading hue as well as row and column

sns.lmplot(x='total_bill',y='tip',data=tips, col='day', row = 'time', hue = 'sex')

# %%
# seperating by columns
#instead of hue
#and rows
#remvoing row to get 1

sns.lmplot(x='total_bill',y='tip',data=tips, col='day', hue = 'sex')

# %%
# seperating by columns
#instead of hue
#and rows
#changing aspect ratio

sns.lmplot(x='total_bill',y='tip',data=tips, col='day', hue = 'sex', aspect = 0.6, size = 8)


# size and aspect ration can be adjusted
# aspect ration = ration btw hegiht and width of each seperate grid
# size
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# seperating by columns
#instead of hue
#and rows
#changing aspect ratio

sns.lmplot(x='total_bill',y='tip',data=tips, col='day', hue = 'sex', aspect = 0.8, height = 8)


# size and aspect ration can be adjusted
# aspect ration = ration btw hegiht and width of each seperate grid
# size

# %% [markdown]
# # Size and Color

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='sex', data = tips)

# %%
#sns.set_style(shift + tab)

sns.set_style('white')
sns.countplot(x='sex', data = tips)

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data = tips)

# %%
sns.set_style('darkgrid')
sns.countplot(x='sex', data = tips)

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data = tips)
sns.despine()

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data = tips)
sns.despine(right = True, left = True, bottom = True)

# %% [markdown]
# # size aspect

# %%
plt.figure(figsize = (12,3))

sns.countplot(x='sex', data = tips)

# %%
#if we want to show it on paper/ poster
# press shift tab inside text_tab
sns.set_context('poster', font_scale = 3)

plt.figure(figsize = (12,3))

sns.countplot(x='sex', data = tips)

# %%
#if we want to show it on paper/ poster
# press shift tab inside text_tab
sns.set_context('notebook', font_scale = 3)

plt.figure(figsize = (12,3))

sns.countplot(x='sex', data = tips)

# %%
#if we want to show it on paper/ poster
# press shift tab inside text_tab
sns.set_context('notebook')

plt.figure(figsize = (12,3))

sns.countplot(x='sex', data = tips)

# %%
sns.lmplot( x = 'total_bill', y ='tip', data = tips, hue = 'sex' )

# %%
sns.lmplot( x = 'total_bill', y ='tip', data = tips, hue = 'sex' , palette ='coolwarm')

# %%
sns.lmplot( x = 'total_bill', y ='tip', data = tips, hue = 'sex' , palette ='seismic')

# %%
https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
https://matplotlib.org/2.0.2/examples/color/colormaps_reference.html
# Out:
#   File "<ipython-input-177-a3485e03aa52>", line 1
#     https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
#            ^
# SyntaxError: invalid syntax
